# %% [markdown]
# # Python basics
#
# by Vikram Khaire
#
# Computational Physics (PH504M) at IIT Tirupati
#
# Date: January 8, 2026
#
# Applicable for version 3.0 and above

# %% [markdown]
# * Printing output: use print(); Print() does not work (python is case sensitive)

# %%
print("Hello class")
# Out:
# Hello class

# %%
print('Hello class') # ' and " are used interchangably
# Out:
# Hello class

# %%
print(2+3-3*10)
# Out:
# -25

# %% [markdown]
# Note: in jupyter notebook or ipython you don't have to write print()

# %%
2+3-3*10
# Out:
# -25

# %%
print(27/11); print(27/9); print(27/10); print(3*4); print(3.0*4)
# Out:
# 2.4545454545454546
# 3.0
# 2.7
# 12
# 12.0

# %% [markdown]
# Note: 1. print statements are seperated by ;
# 2. Division is always float but the multiplication is not unless at least one of the numbers in multiplication is a float

# %%
a=25.0
b=334
c='Hi'
d=False
e=[2, 3, 4.9, 'yes', 'Anjan', True]
print(a); print(b); print(c); print(d); print(e)
# Out:
# 25.0
# 334
# Hi
# False
# [2, 3, 4.9, 'yes', 'Anjan', True]

# %% [markdown]
# * Types of the inputs (Float, Integer, String, Boolean)

# %%
print(type(a))
# Out:
# <class 'float'>

# %%
print(type(b))
# Out:
# <class 'int'>

# %%
print(type(c))
# Out:
# <class 'str'>

# %%
print(type(d))
# Out:
# <class 'bool'>

# %%
print(type(e))
# Out:
# <class 'list'>

# %% [markdown]
# * Operations on different types

# %%
print('a'+'b')
# Out:
# ab

# %% [markdown]
# note that in the cell above a and b were srings and not variable

# %%
print(a+b)
# Out:
# 359.0

# %%
print(c+c)
# Out:
# HiHi

# %%
# power operation
print(2**8)
# Out:
# 256

# %%
# modulo operation -- gives reminder
print(5%3)
# Out:
# 2

# %%
# floor division -- gives integer division
print(7//3)
# Out:
# 2

# %% [markdown]
# True and False are very important booleans

# %%
print(True + False)
# Out:
# 1

# %%
print(True)
# Out:
# True

# %%
print(True**2)
# Out:
# 1

# %%
print(True * False)
# Out:
# 0

# %%
print(True + True)
# Out:
# 2

# %% [markdown]
# ... because True=1 & False=0 (use True not true i.e capital T and not small t)
